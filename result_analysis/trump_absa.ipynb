# %%
import pandas as pd
import matplotlib.pyplot as plt
# from NewsSentiment import TargetSentimentClassifier
from scipy.signal import savgol_filter

# %%
cur_color = "#06cc1d"
dis_color = "#399944"

# %%
cnn = pd.read_csv('../data/output_data/trump_cnn_news_sentiment.csv')
fox = pd.read_csv('../data/output_data/trump_fox_news_sentiment.csv')

# %%
def add_data_to_plot(axes, vendor1, vendor2, mean1, mean2, correlation):
    axes.text(0.02, 0.95, f'Correlation: {round(correlation,4)}',
                           fontdict={'size': 15, 'color':cur_color}, transform=axes.transAxes)
                
    axes.text(0.02, 0.92, f'Mean {vendor2}: {round(mean1,4)},',
                fontdict={'size': 10, 'color':dis_color}, transform=axes.transAxes)
    axes.text(0.02, 0.89, f'Mean {vendor1}: {round(mean2,4)}',
                fontdict={'size': 10, 'color':dis_color}, transform=axes.transAxes)
    return axes

# %%
cnn
# Out:
#                                                   title        date   index  \
# 0     Why Biden is only just about to face his first...  2023-03-03     0.0
# 1     DOJ ramps up its allegations that Texas is 'ju...  2023-03-03     1.0
# 2     Michigan threats deepen America's dangerous ne...  2023-03-03     2.0
# 3     Fair and Balanced? Murdoch's private messages ...  2023-03-03     3.0
# 4     Jim Jordan's first FBI whistleblowers face scr...  2023-03-03     4.0
# ...                                                 ...         ...     ...
# 2395  Trump rally highlighting January 6 case of all...  2022-09-05  2395.0
# 2396  Opinion: Trump's incendiary rally proved Presi...  2022-09-05  2396.0
# 2397  Biden's use of Marines during Philadelphia spe...  2022-09-04  2397.0
# 2398  Raskin says January 6 committee will release i...  2022-09-04  2398.0
# 2399  Trump is back in the headlines, and it may cos...  2022-09-04  2399.0
#
#                                                    text  num_of_sentences  \
# 0     spend some time reading about how the presiden...               2.0
# 1     the justice department is tripling down on its...               7.0
# 2     an alleged threat to kill jewish government le...               9.0
# 3     "we report. you decide." that was the longtime...               3.0
# 4     in his quest to prove the federal government h...               1.0
# ...                                                 ...               ...
# 2395  rep. zoe lofgren, a member of the house panel ...               5.0
# 2396  former president donald trump gave his first p...              21.0
# 2397  as president joe biden stood outside philadelp...               9.0
# 2398  a democratic member of the house select commit...               5.0
# 2399  midterm elections tend to follow a predictable...              14.0
#
#       neg_lbl  pos_lbl  neu_lbl     neg_s     neu_s     pos_s  compound_s  \
# 0         1.0      0.0      0.0  0.436043  0.299039  0.078644   -0.309387
# 1         0.0      0.0      1.0  0.348826  0.586998  0.064177   -0.369097
# 2         1.0      0.0      0.0  0.873502  0.110552  0.015946   -0.900647
# 3         1.0      0.0      0.0  0.572246  0.259521  0.168234   -0.498651
# 4         0.0      0.0      1.0  0.018479  0.547428  0.053496    0.078812
# ...       ...      ...      ...       ...       ...       ...         ...
# 2395      1.0      0.0      0.0  0.458434  0.429609  0.111957   -0.603257
# 2396      1.0      0.0      0.0  0.637257  0.294950  0.067793   -0.698628
# 2397      1.0      0.0      0.0  0.498046  0.321228  0.180727   -0.348238
# 2398      1.0      0.0      0.0  0.845922  0.138632  0.015446   -0.997806
# 2399      1.0      0.0      0.0  0.388126  0.342653  0.269221   -0.107342
#
#       pos  neg  neu  compound  sum_score  rolling_score_sum  \
# 0       0    0    0         0  -0.618775                NaN
# 1       0    0    0         0  -2.583679                NaN
# 2       0    0    0         0  -8.105822                NaN
# 3       0    0    0         0  -1.495954                NaN
# 4       0    0    0         0   0.078812         -12.725418
# ...   ...  ...  ...       ...        ...                ...
# 2395    0    0    0         0  -3.016283          -9.553445
# 2396    0    0    0         0 -14.671189         -18.224635
# 2397    0    0    0         0  -3.134146         -20.795288
# 2398    0    0    0         0  -4.989030         -25.168376
# 2399    0    0    0         0  -1.502784         -27.313433
#
#       rolling_num_sentences  rolling_score_by_senteces
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                      22.0                  -0.578428
# ...                     ...                        ...
# 2395                   16.0                  -0.597090
# 2396                   31.0                  -0.587891
# 2397                   39.0                  -0.533213
# 2398                   43.0                  -0.585311
# 2399                   54.0                  -0.505804
#
# [2400 rows x 20 columns]

# %%
worst_precentile = cnn.compound_s.quantile(0.1)
best_precentile = cnn.compound_s.quantile(0.9)
print("worst_precentile (10%): ", worst_precentile, ". best_precentile (10%): ", best_precentile)

best_precentile = cnn.compound_s.quantile(0.95)
print("best_precentile (5%): ", best_precentile)

cnn[cnn.compound_s < worst_precentile].loc[:, ('title', 'compound_s')].values
# Out:
# worst_precentile (10%):  -0.9270208030342544 . best_precentile (10%):  0.30127017298865966
# best_precentile (5%):  0.6163706051312868
# array([['Colorado discipline office moves toward ethics complaint against ex-Trump attorney for 2020 election gambits',
#         -0.9999999679806376],
#        ['Paul Ryan grilled for remaining on Fox board of directors amid election fraud revelations',
#         -1.0],
#        ["Fox executives should be fired for 'proven misconduct' exposed in Dominion lawsuit, renowned Yale professor says",
#         -1.0],
#        ["Fox faces an 'existential threat' from its multibillion-dollar defamation cases",
#         -0.9999952319679636],
#        ["Opinion: Tim Scott's pitch to Republicans offers more than the usual red meat",
#         -0.9530211889494016],
#        ['Media organizations ask Congress for access to January 6 footage',
#         -0.9705882352941176],
#        ['Judge tosses out disciplinary action against Sidney Powell for work on Trump election reversal bid',
#         -0.9968102449436784],
#        ['Federal prosecutors seek to compel Pence to testify in special counsel probe',
#         -0.9999999999490596],
#        ["Fury over Biden's new asylum policy grows after he thanks Poland for welcoming Ukrainian refugees",
#         -0.9331388027497376],
#        ['Capitol rioter who tweeted threat to Rep. Ocasio-Cortez sentenced to 38 months in prison',
#         -0.9889069113502624],
#        ["Steve Bannon's ex-lawyers sue him over nearly $500,000 in unpaid legal bills",
#         -0.999999968943527],
#        ['Rep. David Cicilline to resign from Congress June 1 to run foundation',
#         -0.999999999999998],
#        ['Analysis: Fox News has been exposed as a dishonest organization terrified of its own audience',
#         -0.9379430325093632],
#        ["Fox News stars and executives privately trashed Trump's election fraud claims, court document reveals",
#         -0.958120633075078],
#        ['Biden administration restores Obama-era mercury rules for power plants, eyes more regulations in coming months',
#         -1.0],
#        ["Arizona Court of Appeals rejects Kari Lake's election challenge",
#         -1.0],
#        ["Newt Gingrich won't have to testify before special grand jury in Georgia",
#         -1.0],
#        ["Trump's former national security adviser Robert O'Brien appears before federal grand jury",
#         -0.9854067500260384],
#        ['READ: Fulton County grand jury releases report on Trump and the 2020 election',
#         -1.0],
#        ['House Judiciary chairman subpoenas big tech executives for company communications with executive branch',
#         -1.0],
#        ['Washington Post: Trump campaign commissioned research that failed to prove 2020 election fraud claims',
#         -0.9848193010830012],
#        ["Republicans held a hearing to prove Twitter's bias against them. It backfired in spectacular fashion",
#         -0.9972866241689284],
#        ["Opinion: The GOP is playing right into Biden's hands",
#         -0.9846562696717822],
#        ['House Oversight chairman and former Twitter employees strike deal on subpoenas in exchange for testimony',
#         -1.0],
#        ['National Enquirer has finally been sold after seeking a buyer for years',
#         -0.999542907634642],
#        ["Biden administration restores protections for Alaska's Tongass forest",
#         -0.9705882352941176],
#        ["Opinion: McCarthy's committee vengeance could pose a grave risk",
#         -0.9424105424465656],
#        ['Homeland Security intel chief describes revamp of department amid radicalization in the US',
#         -1.0],
#        ["Fact check: Kari Lake's continuing false Arizona election claims",
#         -1.0],
#        ["Watchdog says federal government gave $5.4 billion in Covid aid to small businesses with 'questionable' Social Security numbers",
#         -0.950671879574355],
#        ['Justice Department closes foreign lobbying investigation into retired Marine general without filing charges, attorney says',
#         -0.9999939225964938],
#        ["Bipartisan group of House leaders moves to intervene in dispute over accessing Rep. Scott Perry's phone",
#         -0.999999106568156],
#        ['First on CNN: Biden administration to strengthen Obamacare contraceptive mandate in proposed rule',
#         -0.999804097250875],
#        ['Paul Pelosi attacker trafficks in conspiracy theories in call to TV station after video release',
#         -0.9993126900804186],
#        ['Federal prosecutors discussed charging Trump in Stormy Daniels case when he left office, book says',
#         -0.9707202538325048],
#        ['California bar unveils disciplinary charges against Trump lawyer John Eastman',
#         -0.9778691602468608],
#        ["News outlets ask judge to unseal documents in Dominion's defamation case against Fox News",
#         -1.0],
#        ['EPA plans to stop 6 power plants from dumping toxic coal ash into unlined ponds',
#         -1.0],
#        ["Democratic congressman says he is 'profoundly troubled' by Biden document disclosures",
#         -0.9880778858983158],
#        ['First on CNN: New Mexico AG probing campaign finances of GOP candidate accused of orchestrating shootings',
#         -0.9571428571428572],
#        ['Jacinda Ardern, like George Washington, knew when to quit',
#         -0.9999883198034994],
#        ['White House strategy to manage documents fallout takes shape',
#         -0.928284541616208],
#        ["Capitol Police chief says threats against members of Congress 'still too high' despite drop in case numbers",
#         -1.0],
#        ['A famous last name, business deals and a looming probe: Republicans ramp up investigation of Biden family',
#         -0.9637681159258747],
#        ['Signs the White House is beginning to shift documents strategy',
#         -0.982360326423914],
#        ["Manhattan DA Alvin Bragg tells CNN that his office's investigation of Trump Org. will continue",
#         -0.996482389235754],
#        ["Steve Bannon must find new lawyers to advise him in 'We Build the Wall' criminal fraud case",
#         -0.9999999999999968],
#        ['Opinion: The time is now for Social Security and Medicare reform',
#         -0.9999999997937296],
#        ["Paul Ryan says he 'had too much power' as House speaker",
#         -0.9725915614756576],
#        ['NBC News president Noah Oppenheim exits, replaced by new head of editorial and two others in network shakeup',
#         -0.9988051101648469],
#        ["Biden's documents drama gives Republicans a fresh narrative to use against him",
#         -0.9999955491269282],
#        ["Stephanie McMahon resigns as WWE's chairwoman and co-CEO",
#         -0.9999998911930584],
#        ["There are clear distinctions between Trump and Biden's two cases",
#         -0.9805943202199244],
#        ["Musk's Twitter restores accounts of prominent election deniers two years after Jan. 6 attack",
#         -0.999982298674494],
#        ["Déjà coup: How election lies sparked the violent attack on Brazil's government",
#         -1.0],
#        ['Republican Sen. Ben Sasse resigns to become University of Florida president, opening seat for appointment by Nebraska governor',
#         -1.0],
#        ["Opinion: Trump's immigration policy was a fiasco. Why hasn't Biden fixed it yet?",
#         -0.9999978936335993],
#        ['Supreme Court declines to hear another longshot 2020 election fraud challenge',
#         -0.9717716013333576],
#        ["Supreme Court again declines to take up appeal from GOP-led states seeking to intervene in case over 'public charge' immigration policy",
#         -0.9796319439302796],
#        ['Georgia grand jury investigating Trump and 2020 election aftermath completes its work',
#         -1.0],
#        ["Opinion: There's no way to sugarcoat it -- Brazil attacks were opening act of attempted coup",
#         -0.9981046523958051],
#        ['Vince McMahon returns to WWE as a board member',
#         -0.9999999949842774],
#        ['First lady Jill Biden to join president on trip to Mexico City',
#         -1.0],
#        ['Trump accused in lawsuit of causing wrongful death of Officer Brian Sicknick in US Capitol attack',
#         -0.9996818061352948],
#        ['Wall Street Journal: Vince McMahon plots return to WWE', -1.0],
#        ['First on CNN: Biden to honor 12 people with Presidential Citizens Medal on two-year anniversary of January 6 insurrection',
#         -0.9999999999999976],
#        ['The clerk presiding during the speaker vote is no stranger to turbulent times in the House',
#         -0.9999528700724268],
#        ['Roberts calls for judicial security in year-end report while avoiding mention of ethics reform or abortion draft leak',
#         -0.965231841163456],
#        ['Arizona judge orders Kari Lake to compensate Katie Hobbs for some fees for election lawsuit, but declines to sanction her',
#         -1.0],
#        ['Why 2022 was a tough year for Trump and 2023 may not be much better',
#         -0.9636811058836264],
#        ['West Point kicks off process to remove Confederate monuments on campus',
#         -0.9852439690036252],
#        ['El Paso housed more than 300 migrants Friday overnight',
#         -0.9725994892071308],
#        ["Arizona judge rejects Kari Lake's election challenge and confirms Hobbs' victory",
#         -0.9705882352941176],
#        ['House passes $1.7 trillion government spending bill as funding deadline looms',
#         -0.99994765194347],
#        ['Special counsel Durham has spent at least $6.5 million on inquiry into Trump-Russia probe',
#         -0.999999999835148],
#        ['Congress passes first legislative response to January 6 Capitol attack',
#         -0.997933039348342],
#        ['Meta agrees to pay $725 million to settle lawsuit over Cambridge Analytica data leak',
#         -0.9335045797002416],
#        ['5 things to know for December 23: Air travel, Jan. 6, Ukraine, Immigration, NASA',
#         -0.9363636363629972],
#        ['QAnon members in Japan sentenced for breaking into Covid vaccination centers',
#         -0.951373255668519],
#        ['Senate passes $1.7 trillion government funding bill to avert shutdown',
#         -0.9992099435935144],
#        ['House Democrats pick Jamie Raskin to be ranking member on Oversight committee',
#         -1.0],
#        ["READ: Transcripts of Cassidy Hutchinson's depositions with the House January 6 committee",
#         -0.999999999999992],
#        ["5 things to know for December 21: Ukraine, Trump's taxes, Weather, Title 42, Taliban",
#         -0.9999999999999832],
#        ['Elon Musk says he will step down as Twitter CEO — once he finds a replacement',
#         -1.0],
#        ['READ: House Ways and Means Committee report finding Trump was not properly audited by IRS as president',
#         -1.0],
#        ["Lawmakers to push through first legislative response to January 6 Capitol attack by week's end",
#         -0.9959153028814648],
#        ['First on CNN: Biden administration moves to phase out compact fluorescent light bulbs and push market toward LEDs',
#         -0.9999999999999724],
#        ['Biden to name former Rep. Joe Kennedy III as Northern Ireland envoy Monday morning',
#         -0.9968173458665444],
#        ['Everyone can now agree -- the US has a border crisis', -1.0],
#        ["Officer injured on Jan. 6 says resigning wasn't his choice: 'They did that to me, the mob'",
#         -0.9974429159191288],
#        ["Democratic lawmakers urge Meta not to restore Trump's account in January",
#         -0.9786685770408776],
#        ["McCarthy's impossible GOP math", -1.0],
#        ["Justice Department has tried to access GOP Rep. Scott Perry's text messages",
#         -0.9999993299261172],
#        ['Jan. 6 defendant pleads guilty to threatening Rep. Ocasio-Cortez on Twitter',
#         -0.9999999995629414],
#        ["Former top Twitter official forced to leave home due to threats amid 'Twitter Files' release",
#         -1.0],
#        ['January 6 committee ends meeting on criminal referrals', -1.0],
#        ['CNN Pentagon correspondent Barbara Starr is leaving the network after more than two decades',
#         -1.0],
#        ["Elton John is quitting Twitter, saying platform's policy shift will let misinformation flourish",
#         -1.0],
#        ['Pentagon awards multibillion-dollar cloud contract to Amazon, Google, Microsoft and Oracle',
#         -1.0],
#        ["Second gentleman warns of 'rapid rise' in antisemitism during White House roundtable",
#         -0.9999902071967104],
#        ["Warnock will win Georgia Senate runoff, CNN projects, in final midterm rebuke of Trump's influence",
#         -0.9999767352929384],
#        ['5 things to know for Dec. 7: Senate, Trump Organization, Gas prices, Apple, China',
#         -1.0],
#        ['Family of fallen officer snubs McCarthy and McConnell as Congress honors law enforcement who defended the Capitol on Jan. 6',
#         -1.0],
#        ['House January 6 committee has decided to make criminal referrals, chairman says',
#         -0.9385578322541716],
#        ['Michael Avenatti sentenced to 14 years in prison for stealing millions of dollars from clients',
#         -0.999998815357512],
#        ["Supreme Court won't hear case brought by a group of voters against Dominion Voting Systems and Facebook",
#         -1.0],
#        ['Second gentleman Doug Emhoff to convene antisemitism roundtable at the White House this week',
#         -0.9999999582861984],
#        ['2 House Trump investigations, 1 month, many loose ends',
#         -0.9316689402184412],
#        ['Americans have low expectations for the next Congress, new poll finds',
#         -0.9691280183579845],
#        ["Hillary Clinton says US should not engage in nuclear talks with Iran as protestors stand up 'to their oppressors'",
#         -0.9444444444444444],
#        ["House Democrats set to discuss how to handle Trump's tax returns",
#         -0.9947665039843964],
#        ["January 6 committee member says entirety of panel's work will be released in coming weeks",
#         -0.9999999999977564],
#        ["Opinion: The lost meaning of 'gaslighting' is an alarm bell, constantly ringing",
#         -0.9859705042068222],
#        ['Ron DeSantis gets the frontrunner treatment',
#         -0.9999999218645156],
#        ["What the Oath Keepers sedition verdict means for the Justice Department's investigation of Trump",
#         -0.9999999996585224],
#        ["Twitter must comply with Europe's platform rules, EU digital chief warns Musk in virtual meeting",
#         -1.0],
#        ['Conservative activists ordered to spend 500 hours registering voters for running a 2020 voter suppression campaign',
#         -1.0],
#        ["Twitter is less safe due to Elon Musk's management style, says former top official",
#         -0.98],
#        ['Supreme Court justices may finally have to decide if the White House can write immigration rules',
#         -0.9571428484791108],
#        ['South Carolina Supreme Court orders Mark Meadows to testify in Georgia 2020 election meddling investigation',
#         -0.9327574419729382],
#        ["Judge says Trump's political actions around 2020 election not protected by 'absolute immunity'",
#         -0.9999986453047176],
#        ['5 things to know for Nov. 29: Same-sex marriage, World Cup, Strike, Volcano, Twitter',
#         -1.0],
#        ["Believe it -- Merriam-Webster's word of the year is 'gaslighting'",
#         -0.9999950261873845],
#        ['Final January 6 committee report expected to focus on issues beyond Trump efforts',
#         -0.9999960197715806],
#        ['Flood of lawsuits expected as window opens for adult survivors to sue in New York for sexual abuse',
#         -0.999844524163504],
#        ['Alex Jones must pay full $49 million damages award, Texas judge rules',
#         -0.9705882352941176],
#        ['Democratic challenger concedes to Rep. David Valadao in California House race',
#         -1.0],
#        ['Nuclear watchdog says Iran enriching up to 60% at underground Fordow nuclear facility',
#         -0.9999964228360244],
#        ["Democratic Arizona governor-elect says White House isn't 'doing enough' about the border",
#         -1.0],
#        ['Jury deliberations begin in Oath Keepers seditious conspiracy trial',
#         -0.9996356554852628],
#        ["Twitter won't restore Alex Jones' account, Elon Musk says",
#         -0.9999967938124394],
#        ['Who is Hakeem Jeffries, the Democrat seeking to succeed Nancy Pelosi',
#         -0.9999999832772728],
#        ['NBA superstar Luka Doncic says he prefers chess to Twitter',
#         -0.99999999999999],
#        ['Opinion: Buckle up for a bumpy ride, Republicans',
#         -0.9530375243227976],
#        ['Judge dismisses Michael Cohen retaliation lawsuit against Trump',
#         -0.9941270043405502],
#        ["Capitol riot defendant calls himself a 'little bit of a goof' regarding Pelosi and Pence comments",
#         -1.0],
#        ["DeSantis dismisses 'noise' when asked about Trump's criticism of him",
#         -0.9813264844571012],
#        ["Pence: 'I think we'll have better choices in the future' than Trump",
#         -0.9832488830187118],
#        ['Opinion: The voters sent a message to Trump and Biden',
#         -0.957574064817726],
#        ["Dave Chappelle talks Kanye, antisemitism and Trump in 'SNL' monologue",
#         -0.9705882324452212],
#        ['US Customs and Border Protection commissioner is asked to resign, sources say',
#         -0.999999998119877],
#        ['Twitter battles wave of impersonators after launching new paid verification system',
#         -0.9999993476701264],
#        ['Newt Gingrich ordered to testify before Georgia grand jury investigating 2020 election aftermath',
#         -1.0],
#        ["Opinion: It's the extremism, stupid", -0.9999999999997023],
#        ['The votes have been cast. Now comes the race to finish counting -- and the potential legal fights',
#         -0.998718163533085],
#        ['Federal judge dismisses Vindman witness intimidation lawsuit against Giuliani and Trump Jr.',
#         -0.9996626378761831],
#        ["Avalanche of early lawsuits could pave way for disputes over Tuesday's election results",
#         -0.9284537673634052],
#        ['Biden takes aim at GOP election deniers in the final stretch of campaign',
#         -0.9998583696951152],
#        ['A guide to the election deniers in midterm races', -1.0],
#        ['Pillow salesman and Trump ally Mike Lindell loses court bid to reclaim phone seized by FBI, access warrant details',
#         -1.0],
#        ['Jimmy Kimmel says he was going to quit his show if ABC asked him to stop making Trump jokes',
#         -0.999459104130076],
#        ["Democrat Hobbs defends decision not to debate GOP's Lake in tight Arizona gubernatorial race",
#         -0.9444428268576568],
#        ['Federal judge blasts the Supreme Court for its Second Amendment opinion',
#         -1.0],
#        ['The bottom is dropping out of the 2022 election for Democrats',
#         -0.9705882352941176],
#        ['CNN to host town hall with former Vice President Mike Pence',
#         -0.981992463494048],
#        ["US Iran envoy says he is focused on 'where we can be useful' and not going to 'waste our time' on nuclear deal right now",
#         -0.9999999975157858],
#        ["Elon Musk disbands Twitter's board, cementing control over company",
#         -0.956849814147674],
#        ['House majority leader reflects on 20 years since first federal voting systems legislation enactment and how the fight over voting system legitimacy has shifted',
#         -1.0],
#        ['Opinion: A major milestone in the fight for press freedom',
#         -1.0],
#        ["Elon Musk's bumpy road to owning Twitter: A timeline",
#         -0.9878048780436008],
#        ["White House on Ron Klain violating the Hatch Act: 'We are not perfect'",
#         -0.9995816431292572],
#        ["Elon Musk tells advertisers he doesn't want Twitter to become 'free-for-all hellscape'",
#         -0.9976502749617],
#        ['Mark Meadows ordered by court to testify in Georgia 2020 election meddling probe',
#         -0.9288567109850236],
#        ['Arizona and Nevada counties plan to hand count ballots for midterms',
#         -0.9999968943627686],
#        ['5 things to know for Oct. 24: United Kingdom, RSV, Hurricane Roslyn, Trump, Diwali',
#         -0.980728770888566],
#        ['US border encounters top 2 million in fiscal year 2022', -1.0],
#        ['Biden contradicts himself with victory laps on deficit reduction and student loan relief, experts say',
#         -0.9705879099587392],
#        ['Fallout from Truss collapse rattles US democracy, too',
#         -0.9612587696174852],
#        ['Opinion: The real Herschel Walker problem', -1.0],
#        ["Retired Republican judge joins fight against 'centerpiece' of Trump's effort to overturn election",
#         -0.9659009281819526],
#        ["Texas secretary of state's office announces inspection of general election count in most populous county less than week before early voting",
#         -0.9468263606910884],
#        ['5 things to know for October 19: Midterms, Trump, Ukraine, Gas prices, US currency',
#         -0.9999976794659546],
#        ["'Conquer or die': Oath Keeper testifies that the group was ready to stop the election 'by any means necessary'",
#         -0.999566729310437],
#        ["Special master Dearie unhappy with Mar-a-Lago document progress: 'Where's the beef? I need some beef'",
#         -0.9591303596952988],
#        ["Liz Cheney says January 6 committee will issue Trump subpoena 'shortly'",
#         -0.9638278518294748],
#        ['Primary source for Trump-Russia dossier acquitted, handing special counsel Durham another trial loss',
#         -0.9982487720920384],
#        ['Georgia secretary of state candidates spar over their records and impact of controversial voting law in debate',
#         -0.9992175634863192],
#        ['Opinion: How a "Donald Trump in heels" could ruin democracy in Arizona',
#         -0.9446605404756055],
#        ["Opinion: The chilling problem with Kanye West's definition of 'free speech'",
#         -0.9635059069506612],
#        ['What could happen if an election denier is running elections',
#         -0.999999999987203],
#        ["Ron Johnson's campaign paid law firm associated with January 6 false elector scheme for 'recount consulting,' per FEC records",
#         -0.9999985625245712],
#        ['Start your week smart: Snow crabs, China, Russia, Mexico, January 6',
#         -0.9999976794659896],
#        ["Opinion: Trump's all-caps rage is back. Has America changed?",
#         -0.992307692307687],
#        ["Biden says January 6 committee has made an 'overwhelming' case",
#         -0.9485522646453394],
#        ['January 6 panel asks Secret Service for information about contacts between agents and Oath Keeper members',
#         -0.9957299186379654],
#        ['FBI offered Christopher Steele $1 million to prove dossier claims, senior FBI analyst testifies',
#         -0.9626981701277776],
#        ['CIA inspector general dings agency care of early Havana Syndrome victims',
#         -0.9622978364830744],
#        ["Oath Keepers' alleged plans for January 6 come into focus as second week of trial comes to an end",
#         -0.9705882349601792],
#        ['5 things to know for October 14: January 6, Parkland, Raleigh, Ukraine, NASA',
#         -0.9444444444444368],
#        ["Tulsi Gabbard, who sought 2020 Democratic nomination, says she's leaving party",
#         -0.9705882352941176],
#        ['Jake Tapper to sit down with President Joe Biden Tuesday night 9 p.m. ET',
#         -0.9561752674184136],
#        ['The central tension driving the 2022 election',
#         -0.978333900813768],
#        ['Prosecutors argue Graham should have to testify before grand jury in Georgia 2020 investigation',
#         -0.9444444444444444],
#        ["Judge says Oath Keepers jury won't see 'death list'", -1.0],
#        ['Nebraska Republican Ben Sasse to resign his Senate seat to become University of Florida president, source tells CNN',
#         -0.9999880099351356],
#        ['Oath Keepers leader was in touch with US Secret Service in late 2020, former Oath Keeper testifies',
#         -0.9720026694090408],
#        ['Markets are starting to act super strange', -0.9514533790428336],
#        ['Liz Cheney says electing Arizona GOP nominees for governor and secretary of state could put US at risk',
#         -0.9615537406312366],
#        ['US and South Korea test-fire missiles in continued response after North Korea launch',
#         -0.9999999025645688],
#        ['Fact check: Attack ad dishonestly edits 2017 comments from Utah candidate Evan McMullin',
#         -0.9844489857877732],
#        ['5 things to know for Oct. 3: Hurricanes, SCOTUS, Brazil, United Airlines, food recall',
#         -0.9615384395336016],
#        ["Fulton County DA seeks to disqualify attorneys for Republican 'fake electors'",
#         -1.0],
#        ['Supreme Court allows defamation lawsuit against MyPillow CEO Mike Lindell to proceed',
#         -1.0],
#        ["GOP congressional candidate Joe Kent's ties to white nationalists include interview with Nazi sympathizer",
#         -0.9998833569005684],
#        ["Opinion: Casting doubt on Brazil's election, Bolsonaro follows Trump's lead",
#         -0.9999672067819476],
#        ["IG identifies 'concerns' with Defense Department phone messaging apps in probe of missing January 6 texts",
#         -0.9999999997495004],
#        ["DOJ declares seized Mar-a-Lago materials list full and accurate despite Trump's claims of planted evidence",
#         -0.942305951763543],
#        ['Justice Department asks judge to order former Trump adviser Peter Navarro to return federal records',
#         -1.0],
#        ['Schiff says any criminal referral for Trump by the January 6 committee should be decided unanimously',
#         -0.9355971548830948],
#        ['Adam Schiff criticizes slow pace of Justice Department investigation into broader January 6 plot',
#         -0.9999999999985416],
#        ['White House set to conduct a broad talent search in preparation for post-midterms turnover',
#         -1.0],
#        ['Intelligence community restarts work on Mar-a-Lago documents damage assessment',
#         -0.9999998863940968],
#        ["Opinion: DeSantis' actions should raise alarm bells",
#         -0.9898930267443592],
#        ["Opinion: How Trump's terrible day went from bad to worse",
#         -0.957109038943233],
#        ["Tracking Trump's ongoing investigations, civil suits and countersuits",
#         -0.9905768732311904],
#        ["Read: New York's civil fraud lawsuit against Donald Trump and family members",
#         -1.0],
#        ['E. Jean Carroll says she will sue Trump under NY law for sexual assault and wants his deposition',
#         -0.9999999999960628],
#        ["The United Nations' fundamental principles are under threat",
#         -1.0],
#        ['House Oversight Committee rejects GOP effort to probe Hunter Biden',
#         -1.0],
#        ['New footage confirms fake Trump elector spent hours inside Georgia elections office day it was breached',
#         -0.9943598334474328],
#        ['White House surges aid to hurricane-hit Puerto Rico on a haunting five-year anniversary',
#         -0.9989269671183114],
#        ['Opinion: Republicans just gave the country a master class on extremism',
#         -0.9997659669331792],
#        ['More than half of Republican Senate nominees have rejected, cast doubt upon or tried to overturn the 2020 election results',
#         -0.987660784536936],
#        ["Patagonia's founder transfers ownership into two entities to help fight the climate crisis",
#         -0.9999308181357904],
#        ['House January 6 committee seeks more John Eastman emails', -1.0],
#        ['Jeffrey Clark told DC Bar that DOJ search of his home linked to false statements, conspiracy, obstruction investigation',
#         -0.999999999999688],
#        ["Blinken calls Iran's latest response to nuclear deal proposal a 'step backward'",
#         -1.0],
#        ['Republican congressman presents convicted January 6 rioter with flag flown over US Capitol after her release from prison',
#         -0.9999999999999998],
#        ['READ: DOJ and Trump team proposals for special master review',
#         -0.9477172091253396],
#        ["Obama warns of 'malevolence' aimed at democracy in Democratic fundraiser speech",
#         -1.0],
#        ['White House plans to allow up to 125,000 refugees into US for 2023 fiscal year',
#         -1.0],
#        ["READ: DOJ's motion to stay ruling ordering special master review for Mar-a-Lago documents",
#         -0.935651601693794],
#        ['Trump Org. investigation continues, NY district attorney says',
#         -0.9984388315844686],
#        ["Former US attorney says Trump DOJ pressured office to 'aid them politically,' NYT reports",
#         -0.9962897239839642],
#        ['Read: Steve Bannon indictment on New York state charges related to border wall fundraising effort',
#         -1.0],
#        ['Michelle Obama is the latest American woman to speak truth to power',
#         -0.9977284360893712],
#        ["Federal judge plans to rule 'quickly' on Mark Meadows fight against subpoenas from the House January 6 committee",
#         -1.0],
#        ['New Mexico county commissioner and Cowboys for Trump founder removed from elected office for role in US Capitol riot',
#         -0.9985791656898804],
#        ['Democrats implore party to prioritize secretary of state races to help avert 2024 debacle',
#         -0.9999999999999668],
#        ["Raskin says January 6 committee will release its report 'by the end of the year'",
#         -0.997805979034949]], dtype=object)

# %%
cnn[cnn.compound_s > best_precentile].loc[:, ('title', 'compound_s')].values
# Out:
# array([['White House releases ambitious cyber strategy calling for more regulation of vulnerable sectors',
#         0.8771875345562102],
#        ["Opinion: Who's stopping the government from giving Americans relief from crushing student loans",
#         0.6485590542192611],
#        ['The fastest growing metro in the US is looking to a shrinking reservoir to keep the boom going',
#         0.6584496118870106],
#        ['Rep. Elissa Slotkin entering race to succeed retiring Michigan Democratic Sen. Debbie Stabenow',
#         0.9619421447498048],
#        ["Buttigieg says he'll visit East Palestine 'when the time is right,' lays out new rail safety efforts",
#         0.9510170803680182],
#        ["Opinion: Pence's plan for a 'better deal' on Social Security should be a non-starter",
#         0.7439716220517077],
#        ['Adam Frisch announces 2024 campaign after losing to Rep. Lauren Boebert in one of the closest races in 2022',
#         0.8611819233070853],
#        ['A subsidy arms race is kicking off between Europe and America',
#         0.6311475409836055],
#        ['At least $191 billion in pandemic jobless benefits improperly paid, watchdog tells Congress',
#         0.7334976589018187],
#        ['5 things to know for Feb. 8: Biden, Earthquake, Spy balloon, Title 42, LeBron James',
#         0.650943395703915],
#        ['Jim Carrey lists $29M LA mansion while offering a glimpse of his own art',
#         0.9180676214384156],
#        ['Born without hands, Brandon Canesi is playing golf on his own terms',
#         0.6314843681107464],
#        ['Sarah Huckabee Sanders draws sharp contrast with Democrats in GOP rebuttal',
#         0.9770927501992396],
#        ["How to watch President Joe Biden's State of the Union address",
#         0.99551326950835],
#        ["Buttigieg says he won't seek US Senate seat in Michigan in 2024",
#         0.957103328661132],
#        ["Democrats approve shake-up of 2024 calendar but it's far from a done deal",
#         0.6847758474468364],
#        ['Blinken under pressure to push China on role in lethal fentanyl trade when he visits Beijing',
#         0.6282183851894264],
#        ['Sarah Huckabee Sanders to deliver Republican response to State of the Union address',
#         0.9996438497215998],
#        ['Joe Biden and Kevin McCarthy put their brand new relationship to the test with debt ceiling crisis looming',
#         0.6268590410616215],
#        ["Biden's message to McCarthy ahead of critical White House meeting: Show me your plan",
#         0.7839586570633245],
#        ["New Hampshire GOP governor says he's considering 2024 White House bid",
#         0.6560875366169661],
#        ['Jill Biden to present Inauguration Day dresses at the Smithsonian',
#         0.7979765885546335],
#        ['5 things to know for Jan. 25: Classified docs, Tornadoes, Immigration, Covid, Ukraine',
#         0.6647561740214281],
#        ["Proud Boys member testifies about group's culture and celebration of violence",
#         0.6655500285336042],
#        ["The key figures who were on the 'Rust' movie set the day of the shooting",
#         0.6666663676615007],
#        ['Opinion: The debt ceiling debate reveals how House Republicans are weaponizing the government',
#         0.8136817662873389],
#        ['Ohio GOP state Sen. Matt Dolan announces US Senate bid to challenge Sherrod Brown',
#         0.9998992893346712],
#        ['Davos draws record crowds, but its relevance is fading',
#         0.6599999836835185],
#        ["Europe's warm winter is robbing Putin of a trump card",
#         0.6749233375185288],
#        ['Why Black voters are more important in Georgia than in any other state',
#         0.932425781382456],
#        ["White House Covid-19 Response Team's chief science officer to retire",
#         0.9894282359474096],
#        ["Arkansas Gov. Sarah Huckabee Sanders bans use of term 'Latinx' in state documents",
#         0.7410051108125545],
#        ["Nebraska Gov. Pillen appoints Pete Ricketts to Sasse's Senate seat",
#         0.8696733642331868],
#        ["Sarah Huckabee Sanders focuses on education reform as she's sworn in as Arkansas' first female governor",
#         0.7499855107868167],
#        ['McCarthy elected House speaker after days of painstaking negotiations and failed votes',
#         0.8076915686096279],
#        ["Michigan Sen. Debbie Stabenow won't seek reelection in 2024",
#         0.7711809449482182],
#        ["How McCarthy's unprecedented leadership battle is a reflection of Fox News and right-wing media",
#         0.8076923076923077],
#        ['Opinion: Kevin McCarthy is getting schooled in history',
#         0.6800095881197911],
#        ["Byron Donalds: Who is the hard-right's new nominee for speaker?",
#         0.9444310337174492],
#        ['House adjourns after chaotic day without electing a speaker as McCarthy fails to lock down votes',
#         0.9881503751580514],
#        ["Inside McCarthy's struggle to lock down the House speakership",
#         0.7475761715648713],
#        ['The Bidens make an island escape ahead of consequential 2024 announcement',
#         0.6862877886708089],
#        ['Migrants in El Paso face uncertainty after Supreme Court allows Title 42 to remain in effect amid legal challenges',
#         0.7105135380849265],
#        ['2 miles of border fencing installed in El Paso area as migrants surge around Texas',
#         0.762024323112361],
#        ['Opinion: Is no career safe anymore?', 0.6843928274341666],
#        ["Opinion: Zelensky's powerful message to Putin",
#         0.651710433009851],
#        ["Why Zelensky's surprise US visit is so hugely significant",
#         0.6629645733160966],
#        ['McCarthy takes a hard line against any senator who backs spending deal',
#         0.6918774885200333],
#        ["Opinion: What 2022's elections taught me about humanity, politics and 'magic sauce'",
#         0.6462810155614392],
#        ['Two migrant buses arrived in New York City on Sunday and up to 15 more are expected in the next few days',
#         0.8333256061491419],
#        ['Border authorities are encountering up to 1,200 migrants a day in South Texas, source says',
#         0.7307361599458722],
#        ['Eric Adams: Democrats can no longer take these voters for granted',
#         0.686046511627907],
#        ["Recount reconfirms GOP Rep. Lauren Boebert's victory in Colorado's 3rd District",
#         0.9237266508051348],
#        ['Trevor Noah celebrates his last episode hosting "The Daily Show" after 7 years behind the desk',
#         0.7666666666666224],
#        ['The most shocking Senate result: Every incumbent won',
#         0.7758620689028083],
#        ['This tattoo removal studio will laser off your Kanye West tattoo for free',
#         0.9999999999994093],
#        ['Opinion: Why Kevin McCarthy may have the hardest job on Capitol Hill',
#         0.7579431621766886],
#        ['Bill Clinton reports mild symptoms after testing positive for Covid-19',
#         0.9685076286208064],
#        ['The fine print of the Respect for Marriage Act',
#         0.6702104483799919],
#        ['Who will lead the Republican Party?', 0.6862990899796282],
#        ["Opinion: Bombshell report deals another blow to the Supreme Court's reputation",
#         0.6912345910764589],
#        ['Democrat concedes to GOP Rep. Lauren Boebert in tight Colorado House race',
#         0.9475533799334682],
#        ['Democrat Katie Porter will win reelection in California, CNN projects',
#         0.7077734230716488],
#        ["3 takeaways from Biden's trip to summits in Egypt, Cambodia and Indonesia",
#         0.6615845476520612],
#        ['Rihanna would like Beyoncé to model for Savage X Fenty',
#         0.9999938218968464],
#        ['Start your week smart: Midterms, Iran, Covid-19, Air show crash, Dolly Parton',
#         0.6755588345769327],
#        ['Boebert expresses optimism but casts blame on her party with her reelection bid still too close to call',
#         0.8478260845744551],
#        ['Kevin McCarthy moves quickly to secure potential speakership as hard-right group weighs a long-shot challenge',
#         0.7743564050349708],
#        ['The single most important number from the midterm exit polls',
#         0.7321705412168334],
#        ['Kathy Hochul wins full term as New York governor',
#         0.9954264158641276],
#        ['CNN Projection: Republican Sarah Huckabee Sanders will win Arkansas governorship',
#         0.6578600229524721],
#        ['7 races that will reveal what kind of election 2022 will be',
#         0.6746869878919671],
#        ['Opinion: What a Netanyahu comeback means for Israel -- and the world',
#         0.6362235862478094],
#        ["Kari Lake was a Fox TV anchor for decades. Her old station isn't telling viewers.",
#         0.9],
#        ['Battle over House seat in California is a wake-up call about the importance of Asian American voters',
#         0.6249999999998832],
#        ['5 very scary numbers for Democrats in the new CNN poll',
#         0.8333333333333169],
#        ['The Senate playing field is moving toward Republicans',
#         0.7576563713903245],
#        ["'God Forbid' revisits the Falwell sex scandal from the 'pool boy's' point of view",
#         0.9319239316831917],
#        ['Oath Keepers spent over $400 at post-US Capitol riot feast at the Olive Garden, prosecutors say',
#         0.8757232877392896],
#        ['A spooky forecast for the future of interest rates',
#         0.6281562738676356],
#        ['Anxious Twitter users find few alternatives to platform after Musk deal closes',
#         0.9187683206851164],
#        ["Twitter confirms completion of Elon Musk's $44 billion acquisition deal",
#         0.638724627450415],
#        ['Hassan and Bolduc spar over abortion and election denial in testy New Hampshire Senate debate',
#         0.6702127658084492],
#        ["Phil Mickelson says Saudi-backed LIV Golf series is 'not going away'",
#         0.8111186113959568],
#        ["Why Republicans shouldn't take the Ohio Senate race for granted",
#         0.7758620689655172],
#        ['GOP candidates seize on decision about Covid-19 vaccines for children as a rallying cry for parental rights',
#         0.6375364621876247],
#        ['The 2022 election is what we thought it was',
#         0.9992749205734208],
#        ['The trick Republicans are using to justify supporting election deniers',
#         0.6818126749585189],
#        ['How a McConnell-linked group is closing the ad spending gap with Democrats in key Senate races',
#         0.6566460855682879],
#        ['Google approves Truth Social for the Google Play Store',
#         0.9958072459477838],
#        ['Washington Post: Woman says she had to push Herschel Walker to pay for abortion he wanted her to have',
#         0.6992980095668283],
#        ["CNN Poll: Biden's approval rises, but national economic outlook remains gloomy",
#         0.7285707975684397],
#        ['Abortion is a key motivator for US voters in midterm elections, new survey finds',
#         0.8809523809523809],
#        ['Biden finalizes new rules for US drone strikes',
#         0.7800849070174879],
#        ["'It hurts the business': Wisconsin Senate race could hinge on voters' views of economy, inflation",
#         0.7623293471906912],
#        ['Who is Christian Walker, the son of Georgia Senate candidate Herschel Walker?',
#         0.727381187130948],
#        ["'Little Fires Everywhere' author says new novel's dystopic vision is 'plausible — and plausible soon'",
#         0.6809379646391447],
#        ["It's been a very bad 24 hours for Herschel Walker",
#         0.9981350220409484],
#        ['This is the bar Joe Biden will have to clear in 2024',
#         0.7615459225390909],
#        ['Opinion: Aaron Judge had a season for the ages. MLB robbed him -- and us',
#         0.6428560843954009],
#        ['Jury seated in Oath Keepers seditious conspiracy trial',
#         0.8558626368452824],
#        ["'This is not the best job in the world': Manchin says he hasn't made any decisions on running again",
#         0.897206236111449],
#        ["Republicans are doing everything they can to lose the Pennsylvania governor's race",
#         0.8510376980554368],
#        ["Joe Manchin is already Republicans' next top target",
#         0.8478260869565217],
#        ["Mitch McConnell's new favorite Democrat", 0.8199637863427983],
#        ['GOP congressional committee cancels ad reservations in key House race in Ohio',
#         0.9849975194332428],
#        ['Ranking the 2024 Democratic field', 0.624682048891821],
#        ['This expert says the lies about 2020 are a threat to democracy',
#         0.626984126984127],
#        ["Opinion: DeSantis chose Martha's Vineyard for a reason",
#         0.9981337091063625],
#        ["Sarah Huckabee Sanders says she is 'cancer-free' after having thyroid and surrounding lymph nodes removed",
#         0.7607070036769107],
#        ["The *real* question to ask about Joe Biden's rising approval numbers",
#         0.8636363636363636],
#        ['In Wisconsin, Republicans attack Mandela Barnes on crime, offering glimpse at shifting midterm message',
#         0.6786244406868701],
#        ['First on CNN: Biden to nominate new ambassador to Russia',
#         0.846398717792298],
#        ["This lingering issue isn't going away for John Fetterman",
#         0.7076404269735176],
#        ['The weirdest campaign in the country is happening in Pennsylvania',
#         0.7962961251329618],
#        ['One thing Americans agree on? Our politicians are too old.',
#         0.6250532860359725],
#        ["The next big Democratic star (you haven't heard of yet)",
#         0.8478184789813842],
#        ["Obamacare can't require coverage for certain HIV prevention drugs, federal judge rules",
#         0.667159831506921],
#        ['Opinion: America has a problem. We, my fellow progressives, must admit it',
#         0.6739130414837371],
#        ['Opinion: Democrats are missing a big opportunity',
#         0.7499997335415729]], dtype=object)

# %%
cnn.head(3)
# Out:
#                                                title        date  index  \
# 0  Why Biden is only just about to face his first...  2023-03-03    0.0
# 1  DOJ ramps up its allegations that Texas is 'ju...  2023-03-03    1.0
# 2  Michigan threats deepen America's dangerous ne...  2023-03-03    2.0
#
#                                                 text  num_of_sentences  \
# 0  spend some time reading about how the presiden...               2.0
# 1  the justice department is tripling down on its...               7.0
# 2  an alleged threat to kill jewish government le...               9.0
#
#    neg_lbl  pos_lbl  neu_lbl     neg_s     neu_s     pos_s  compound_s  pos  \
# 0      1.0      0.0      0.0  0.436043  0.299039  0.078644   -0.309387    0
# 1      0.0      0.0      1.0  0.348826  0.586998  0.064177   -0.369097    0
# 2      1.0      0.0      0.0  0.873502  0.110552  0.015946   -0.900647    0
#
#    neg  neu  compound  sum_score  rolling_score_sum  rolling_num_sentences  \
# 0    0    0         0  -0.618775                NaN                    NaN
# 1    0    0         0  -2.583679                NaN                    NaN
# 2    0    0         0  -8.105822                NaN                    NaN
#
#    rolling_score_by_senteces
# 0                        NaN
# 1                        NaN
# 2                        NaN

# %%
def date_from_recet_only(df):
    df.date = [pd.to_datetime(date).strftime("%Y-%m-%d") for date in df.date]
    df = df[df['date'] > '2022-11-01']
    df = df.sort_values(by='date')
    return df

# cnn = date_from_recet_only(cnn)
# fox = date_from_recet_only(fox)

# %%
def pad_zeroes(numbertext):
    if len(numbertext) == 1:
        return '0' + numbertext
    return numbertext

def add_week_month(df:pd.DataFrame):
    df['date'] = pd.to_datetime(df['date'])
    df['week'] = df['date'].dt.year.astype(str) + '-'  + df['date'].dt.week.astype(str) 
    df['month'] = df['date'].dt.year.astype(str) + '-' + df['date'].dt.month.astype(str).apply(pad_zeroes)
    return df

cnn = add_week_month(cnn)
fox = add_week_month(fox)
# Out:
# /tmp/ipykernel_3106/3782648422.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['date'].dt.year.astype(str) + '-'  + df['date'].dt.week.astype(str)
# /tmp/ipykernel_3106/3782648422.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['date'].dt.year.astype(str) + '-'  + df['date'].dt.week.astype(str)

# %%
def monthly_avg_plot(df1:pd.DataFrame, vendor1, color='#4287f5', df2:pd.DataFrame = None, vendor2=None, color2='#f56342'):
            
            df1['date'] = pd.to_datetime(df1['date'])
            df1 = df1.sort_values(by=['date'], ascending=True)
            df1 = df1.groupby('month').median().rename(columns={'compound_s': vendor1})
            axes = df1.plot(y=vendor1, kind='line',
                             title=f'{vendor1} and {vendor2} News Sentiment', color=color , figsize=(17,8))
            correlation, mean1, mean2 = None, None, None
            if (df2 is not None):
                df2['date'] = pd.to_datetime(df2['date'])
                df2 = df2.sort_values(by=['date'], ascending=True)
                df2 = df2.groupby('month').median().rename(columns={'compound_s': vendor2})
                correlation = df2[vendor2].corr(df1[vendor1])
                mean1 = df1[vendor1].mean()
                mean2 = df2[vendor2].mean()

                df2.plot(y=vendor2, kind='line', ax=axes, color=color2)
                add_data_to_plot(axes, vendor1, vendor2, mean1, mean2, correlation)

            pd.DataFrame({'month': df1.index, 'baseline': [0.0]*len(df1)}).plot(
                    x='month', y='baseline', kind='line', ax=axes, color='#40464f', linestyle='--')
            return df1, df2, correlation, mean1, mean2

def weekly_avg_plot(df1:pd.DataFrame, vendor1, color='#4287f5', df2:pd.DataFrame = None, vendor2=None, color2='#f56342'):       
                df1['date'] = pd.to_datetime(df1['date'])
                df1 = df1.sort_values(by=['week'], ascending=True)
                df1 = df1.groupby('week').median().rename(columns={'compound_s': vendor1})
                axes = df1.plot(y=vendor1, kind='line', title=f'{vendor1} and {vendor2} News Sentiment', color=color , figsize=(17,8))

                if (df2 is not None):
                    df2['date'] = pd.to_datetime(df2['date'])
                    df2 = df2.sort_values(by=['week'], ascending=True)
                    df2 = df2.groupby('week').median().rename(columns={'compound_s': vendor2})
                    correlation = df2[vendor2].corr(df1[vendor1])
                    mean1 = df1[vendor1].mean()
                    mean2 = df2[vendor2].mean()
                    add_data_to_plot(axes, vendor1, vendor2, mean1, mean2, correlation)
    
                    df2.plot(y=vendor2, kind='line', ax=axes, color=color2)
                pd.DataFrame({'week': df1.index, 'baseline': [0.0]*len(df1)}).plot(x='week', y='baseline', kind='line', ax=axes, color='#40464f', linestyle='--')
    


weekly_avg_plot(cnn, 'CNN')
weekly_avg_plot(fox, 'Fox', color='#f56342')
weekly_avg_plot(cnn, 'CNN', df2=fox, vendor2='Fox', color2='#f56342')
monthly_avg_plot(fox, 'Fox', color='#f56342')
monthly_avg_plot(cnn, 'CNN')
cnn_month, fox_month, correlation, mean_cnn, mean_fox = monthly_avg_plot(cnn, 'CNN', df2=fox, vendor2='Fox', color2='#f56342')
# Out:
# /tmp/ipykernel_3106/2107088742.py:27: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('week').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:27: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('week').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:27: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('week').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:33: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df2.groupby('week').median().rename(columns={'compound_s': vendor2})
# /tmp/ipykernel_3106/2107088742.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('month').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('month').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.groupby('month').median().rename(columns={'compound_s': vendor1})
# /tmp/ipykernel_3106/2107088742.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df2.groupby('month').median().rename(columns={'compound_s': vendor2})

# %%
cnn_month = cnn_month.loc[:, ('CNN')]
fox_month = fox_month.loc[:, ('Fox')]
cnn_month.to_csv('cnn.csv', index=True)
fox_month.to_csv('fox.csv', index=True)

# %%
cnn.columns
# Out:
# Index(['title', 'date', 'index', 'text', 'num_of_sentences', 'neg_lbl',
#        'pos_lbl', 'neu_lbl', 'neg_s', 'neu_s', 'pos_s', 'compound_s', 'pos',
#        'neg', 'neu', 'compound', 'sum_score', 'rolling_score_sum',
#        'rolling_num_sentences', 'rolling_score_by_senteces', 'week', 'month'],
#       dtype='object')

# %%
fox.iloc[fox.compound_s.argmin()]['title']
# Out:
# "'Hang Mike Pence' trends on Twitter after platform suspends Trump ..."

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def plot_smooth(df:pd.DataFrame, vendor):
    df = df.sort_values(by=['date'])
    df = df.groupby('month').mean()
    df[vendor] = savgol_filter(df['compound_s'], 10, 2)
    axes = df.plot(y=vendor, kind='line', title=f'{vendor}' , figsize=(17,8))



plot_smooth(cnn, 'CNN')
plot_smooth(fox, 'Fox')
# Out:
# /tmp/ipykernel_1004/716468951.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby('month').mean()
# /tmp/ipykernel_1004/716468951.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby('month').mean()

# %%
# def add_month(row):
#     row['month'] = row['date'].split('-')[0] + '-' + row['date'].split('-')[1]
#     return row

# cnn = cnn.apply(add_month, axis=1)

def plot_counts(df:pd.DataFrame, vendor):
    df = df.sort_values(by=['month'])
    df.groupby('month').agg({'pos_lbl':'sum', 'neg_lbl':'sum', 'neu_lbl':'sum'}).plot(kind='bar', title=f'{vendor} News Sentiment', figsize=(17,8))

plot_counts(cnn, 'CNN')
plot_counts(fox, 'Fox')
# cnn

# %%
fox[cnn.month == '2021-12']
# Out:
# /tmp/ipykernel_1004/1716331973.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fox[cnn.month == '2021-12']
# Empty DataFrame
# Columns: [title, date, index, text, num_of_sentences, neu_lbl, pos_lbl, neg_lbl, neg_s, neu_s, pos_s, compound_s, pos, neg, neu, compound, sum_score, rolling_score_sum, rolling_num_sentences, rolling_score_by_senteces, week, month]
# Index: []
#
# [0 rows x 22 columns]
